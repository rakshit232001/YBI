# %% [markdown]
# # **Title of Project : Big Sales Prediction using Random Forest Regressor**

# %% [markdown]
# **Data Set Information:**
#
# 1. Item_Identifier ---- Unique product ID
#
# 2. Item_Weight ---- Weight of product
#
# 3. Item_Fat_Content ---- Whether the product is low fat or not
# 4. Item_Visibility ---- The % of the total display area of all products in a store allocated to the particular product
# 5. Item_Type ---- The category to which the product belongs
# 6. Item_MRP ---- Maximum Retail Price (list price) of the product
# 7. Outlet_Identifier ---- Unique store ID
# 8. Outlet_Establishment_Year ---- The year in which the store was established
# 9. Outlet_Size ---- The size of the store in terms of ground area covered
# 10. Outlet_Location_Type ---- The type of city in which the store is located
# 11. Outlet_Type ---- Whether the outlet is just a grocery store or some sort of supermarket
# 12. Item_Outlet_Sales ---- sales of the product in t particular store. This is the outcome variable to be predicted.

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd
import numpy as np
import os
from IPython.display import Image
from scipy.stats import mode
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
# Viz lib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load data

# %%
train_df = pd.read_csv('/content/Train.csv')
test_df = pd.read_csv('/content/Test (1).csv')
display(train_df.sample(5))
display(test_df.sample(5))
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3648           FDW27         5.86          Regular         0.151159
# 937            FDG52        13.65          Low Fat         0.065576
# 8322           NCE42        21.10          Low Fat         0.010602
# 1004           DRG03        14.50          Low Fat         0.061935
# 2622           FDA04        11.30          Regular         0.066717
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 3648          Meat  156.6314            OUT045                       2002
# 937   Frozen Foods   47.7402            OUT013                       1987
# 8322     Household  235.3958            OUT046                       1997
# 1004         Dairy  154.4998            OUT013                       1987
# 2622  Frozen Foods  260.8962            OUT035                       2004
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 3648         NaN               Tier 2  Supermarket Type1          3257.7594
# 937         High               Tier 3  Supermarket Type1           643.1628
# 8322       Small               Tier 1  Supermarket Type1          3271.7412
# 1004        High               Tier 3  Supermarket Type1          1691.7978
# 2622       Small               Tier 2  Supermarket Type1          4920.9278
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2334           FDT39         6.26          Regular         0.009860
# 5354           FDE21        12.80          Low Fat         0.023074
# 774            FDE36          NaN          Regular         0.073138
# 5417           DRI23        18.85          Low Fat         0.137083
# 1682           NCN17          NaN          Low Fat         0.054673
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 2334                   Meat  151.8366            OUT013
# 5354  Fruits and Vegetables  117.8492            OUT017
# 774            Baking Goods  162.5868            OUT019
# 5417            Hard Drinks  162.3578            OUT013
# 1682     Health and Hygiene  101.0358            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2334                       1987        High               Tier 3
# 5354                       2007         NaN               Tier 2
# 774                        1985       Small               Tier 1
# 5417                       1987        High               Tier 3
# 1682                       1985      Medium               Tier 3
#
#             Outlet_Type
# 2334  Supermarket Type1
# 5354  Supermarket Type1
# 774       Grocery Store
# 5417  Supermarket Type1
# 1682  Supermarket Type3

# %%
print(f"Shape of train data: {train_df.shape}")
print(f"Shape of test data : {test_df.shape}")
# Out:
# Shape of train data: (8523, 12)
# Shape of test data : (5681, 11)

# %%
# Create source feature to concat train and test data together
train_df['source'] = "train"
test_df['source'] = "test"
test_df['Item_Outlet_Sales'] = 0

# Concat two dataframe
df = pd.concat([train_df,test_df],sort=False,ignore_index=True)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %%
display(f"Length of dataframe : {len(df)}")
# Out:
# 'Length of dataframe : 14204'

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# source                        object
# dtype: object

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'source'],
#       dtype='object')

# %%
describe_df = df.describe()
display(describe_df)
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count       14204.000000
# mean         1308.865489
# std          1699.791423
# min             0.000000
# 25%             0.000000
# 50%           559.272000
# 75%          2163.184200
# max         13086.964800

# %% [markdown]
# ## Null Value

# %%
number_nullvalue = df.isnull().sum().sort_values(ascending=False)
number_nullvalue
# Out:
# Outlet_Size                  4016
# Item_Weight                  2439
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# source                          0
# dtype: int64

# %%
plt.figure(figsize = (25,10))
sns.barplot(x = number_nullvalue.index,y = number_nullvalue.values)
# Out:
# <Axes: >

# %% [markdown]
# **We can see null value appear only in `Item_Weight` and `Outlet_Identifier` column** 😅

# %% [markdown]
# ## Outlier value

# %%
outlier_columns = []
for col in describe_df.columns:
    Q1,Q2,Q3 = describe_df.loc['25%',col],describe_df.loc['50%',col],describe_df.loc['75%',col]
    IQR = Q3 - Q1
    
    upper = Q3 + 1.5*IQR
    lower = Q1 - 1.5*IQR
    outlier_data = df[(df[col] > upper) | (df[col] < lower)].index
    if len(outlier_data) > 0:
        outlier_columns.append(col)
    display(f"{col} has {len(outlier_data)} outlier values")
# Out:
# 'Item_Weight has 0 outlier values'
# 'Item_Visibility has 261 outlier values'
# 'Item_MRP has 0 outlier values'
# 'Outlet_Establishment_Year has 0 outlier values'
# 'Item_Outlet_Sales has 465 outlier values'

# %%
outlier_columns
# Out:
# ['Item_Visibility', 'Item_Outlet_Sales']

# %% [markdown]
# **`Item_Visibility` and `Item_Outlet_Sales` has outlier value but `Item_Outlet_Sales` is target so we process only `Item_Visibility` column**

# %% [markdown]
# ## Verify Incosistent Value

# %%
category_col = [col for col in df.columns if df[col].dtype == 'O']
category_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'source']

# %% [markdown]
# `Item_Identifier` is id for indentify product so we don't have any consistent value in this columns

# %%
for col in category_col:
    display(f"Column : {col}")
    display(df[col].value_counts())
    display("------------------------------------")
# Out:
# 'Column : Item_Identifier'
# FDU15    10
# FDS25    10
# FDA38    10
# FDW03    10
# FDJ10    10
#          ..
# FDR51     7
# FDM52     7
# DRN11     7
# FDH58     7
# NCW54     7
# Name: Item_Identifier, Length: 1559, dtype: int64
# '------------------------------------'
# 'Column : Item_Fat_Content'
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
# '------------------------------------'
# 'Column : Item_Type'
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
# '------------------------------------'
# 'Column : Outlet_Identifier'
# OUT027    1559
# OUT013    1553
# OUT049    1550
# OUT046    1550
# OUT035    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64
# '------------------------------------'
# 'Column : Outlet_Size'
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64
# '------------------------------------'
# 'Column : Outlet_Location_Type'
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
# '------------------------------------'
# 'Column : Outlet_Type'
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64
# '------------------------------------'
# 'Column : source'
# train    8523
# test     5681
# Name: source, dtype: int64
# '------------------------------------'

# %% [markdown]
# **We can see `Item_Fat_Content` has consistent value**

# %% [markdown]
# ## Skewness

# %%
df.skew()
# Out:
# <ipython-input-16-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Item_Weight                  0.101309
# Item_Visibility              1.195175
# Item_MRP                     0.130728
# Outlet_Establishment_Year   -0.396465
# Item_Outlet_Sales            1.544684
# dtype: float64

# %% [markdown]
# **`Item_Visibility` need to process the skewness** 😊

# %% [markdown]
# # Data Visualization

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'source'],
#       dtype='object')

# %%
numeric_feature = [col for col in df.columns if df[col].dtype != "O"]
category_feature = [col for col in df.columns if df[col].dtype == "O"]
display(f"numeric_feature : {numeric_feature}") 
display(f"category_feature : {category_feature}")
# Out:
# "numeric_feature : ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']"
# "category_feature : ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'source']"

# %%
# importing packages 
import seaborn as sns 
import matplotlib.pyplot as plt
  
# current colot palette

# %%
fig,ax = plt.subplots(nrows=1,ncols=3, figsize=(25,10))
# Item_Weight
# Note : can use histplot for many column have Nan value
sns.histplot(ax=ax[0],data = df.dropna(),x = 'Item_Weight',kde=True,palette='bright')
ax[0].set_title('Item Weight')

# Item_Visibility
sns.boxplot(ax = ax[1],data=df, x ='Item_Visibility',color='blue',palette='muted')
ax[1].set_title('Item Visibility')

# Item_MRP
sns.kdeplot(ax = ax[2],data = df['Item_MRP'],shade = True,color='green')
ax[2].set_title('Item_MRP')
# Out:
# <ipython-input-20-4e111e73f8d3>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(ax=ax[0],data = df.dropna(),x = 'Item_Weight',kde=True,palette='bright')
# <ipython-input-20-4e111e73f8d3>:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax = ax[2],data = df['Item_MRP'],shade = True,color='green')
# Text(0.5, 1.0, 'Item_MRP')

# %%
# Category
feature = 'Item_Fat_Content'
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
df[feature].value_counts().plot.pie(autopct = "%1.1f%%")
plt.subplot(1,2,2)
sns.countplot(x = feature,data=df)
plt.show()

# %% [markdown]
# **We can see `low fat`,`LF`,`reg` is inconsitent data**

# %%
feature = 'Outlet_Location_Type'
sns.countplot(data = df,x = feature)
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='count'>

# %%
category_feature
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'source']

# %%
plt.figure(figsize=(15,10))
feature = 'Item_Type'
df[feature].value_counts().plot.pie(autopct = "%1.1f%%")
plt.show()

# %%
feature1 = 'Outlet_Location_Type'
feature2 = 'Outlet_Type'
display(pd.crosstab(df[feature1],df[feature2],margins = True))
plt.figure(figsize = (15,5))
sns.stripplot(data = df,x = feature1,y = feature2)
plt.show()
# Out:
# Outlet_Type           Grocery Store  Supermarket Type1  Supermarket Type2  \
# Outlet_Location_Type
# Tier 1                          880               3100                  0
# Tier 2                            0               4641                  0
# Tier 3                          925               1553               1546
# All                            1805               9294               1546
#
# Outlet_Type           Supermarket Type3    All
# Outlet_Location_Type
# Tier 1                                0   3980
# Tier 2                                0   4641
# Tier 3                             1559   5583
# All                                1559  14204

# %%
feature1 = 'Item_Visibility'
feature2 = 'Outlet_Type'
display(pd.crosstab(df[feature1],df[feature2],margins = True))
plt.figure(figsize = (15,5))
sns.stripplot(x = df[feature1],y = df[feature2])
plt.show()
# Out:
# Outlet_Type      Grocery Store  Supermarket Type1  Supermarket Type2  \
# Item_Visibility
# 0.0                        103                577                103
# 0.003574698                  0                  0                  0
# 0.003589104                  0                  1                  0
# 0.003591414                  0                  1                  0
# 0.003592093                  0                  1                  0
# ...                        ...                ...                ...
# 0.32111501                   1                  0                  0
# 0.323637245                  1                  0                  0
# 0.325780807                  1                  0                  0
# 0.328390948                  1                  0                  0
# All                       1805               9294               1546
#
# Outlet_Type      Supermarket Type3    All
# Item_Visibility
# 0.0                             96    879
# 0.003574698                      1      1
# 0.003589104                      0      1
# 0.003591414                      0      1
# 0.003592093                      0      1
# ...                            ...    ...
# 0.32111501                       0      1
# 0.323637245                      0      1
# 0.325780807                      0      1
# 0.328390948                      0      1
# All                           1559  14204
#
# [13007 rows x 5 columns]

# %%
numeric_feature
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales']

# %%
feature1 = 'Item_Visibility'
feature2 = 'Item_MRP'
plt.figure(figsize = (15,10))
sns.scatterplot(data = df,x = feature2,y = feature1,)
plt.show()

# %%
feature1 = 'Outlet_Location_Type'
feature2 = 'Item_Outlet_Sales'
feature3 = 'Outlet_Type'

plt.figure(figsize = (15,5))
sns.boxplot(data = df,x = feature1, y = feature2,hue = feature3)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.heatmap(df.corr(),annot = True)
plt.show()
# Out:
# <ipython-input-30-92f43194a9cf>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# We had seen `Item_Fat_Content` is inconsistent before => handle inconsistent in `Item_Fat_Content`

# %%
feature = 'Item_Fat_Content'
df[feature].value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
df[feature].replace(to_replace = 'LF',value = 'Low Fat',inplace=True)
df[feature].replace(to_replace= 'low fat',value = 'Low Fat',inplace=True)
df[feature].replace(to_replace= 'reg',value = 'Regular',inplace = True)

# %%
df[feature].value_counts()
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
#  **Missing value**

# %%
check_null_val = pd.DataFrame(df.isnull().sum(),columns=['Number_null_value'])
check_null_val
# Out:
#                            Number_null_value
# Item_Identifier                            0
# Item_Weight                             2439
# Item_Fat_Content                           0
# Item_Visibility                            0
# Item_Type                                  0
# Item_MRP                                   0
# Outlet_Identifier                          0
# Outlet_Establishment_Year                  0
# Outlet_Size                             4016
# Outlet_Location_Type                       0
# Outlet_Type                                0
# Item_Outlet_Sales                          0
# source                                     0

# %%
feature_null_val = list(check_null_val[check_null_val['Number_null_value'] > 0].index)
feature_null_val
# Out:
# ['Item_Weight', 'Outlet_Size']

# %% [markdown]
# **Item_Weight**

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %%
null_feature = 'Item_Weight'
pivot_feature = 'Item_Identifier'
table_weight = df.pivot_table(values= null_feature,index= pivot_feature, aggfunc = 'mean')
table_weight.head(),table_weight.shape
# Out:
# (                 Item_Weight
#  Item_Identifier
#  DRA12                 11.600
#  DRA24                 19.350
#  DRA59                  8.270
#  DRB01                  7.390
#  DRB13                  6.115,
#  (1559, 1))

# %%
table_weight.index
# Out:
# Index(['DRA12', 'DRA24', 'DRA59', 'DRB01', 'DRB13', 'DRB24', 'DRB25', 'DRB48',
#        'DRC01', 'DRC12',
#        ...
#        'NCZ05', 'NCZ06', 'NCZ17', 'NCZ18', 'NCZ29', 'NCZ30', 'NCZ41', 'NCZ42',
#        'NCZ53', 'NCZ54'],
#       dtype='object', name='Item_Identifier', length=1559)

# %% [markdown]
# **Replace null value by mean of all product had same `Item_Identifier`**

# %%
index_null_val = list(df[df[null_feature].isnull() == True].index)
len(index_null_val)
# Out:
# 2439

# %%
replace_series ={idx:table_weight.loc[df.loc[idx,'Item_Identifier'],'Item_Weight'] for idx in index_null_val}
replace_series
# Out:
# {7: 19.0,
#  18: 8.26,
#  21: 8.315,
#  23: 15.5,
#  29: 14.5,
#  36: 20.2,
#  38: 6.385,
#  39: 15.25,
#  49: 10.195000000000002,
#  59: 5.94,
#  62: 6.215,
#  63: 15.5,
#  64: 17.5,
#  77: 13.35,
#  83: 18.85,
#  84: 12.6,
#  87: 20.2,
#  95: 7.93,
#  98: 12.15,
#  101: 20.6,
#  108: 9.395,
#  112: 6.69,
#  113: 6.195,
#  130: 12.0,
#  132: 12.15,
#  136: 18.25,
#  153: 9.5,
#  161: 21.35,
#  168: 14.6,
#  178: 9.395,
#  180: 14.0,
#  182: 10.0,
#  184: 6.215,
#  186: 11.1,
#  194: 17.6,
#  198: 15.6,
#  199: 4.615,
#  203: 10.3,
#  208: 5.175,
#  225: 9.06,
#  227: 8.93,
#  229: 16.7,
#  230: 6.36,
#  231: 5.365,
#  235: 9.3,
#  236: 17.6,
#  238: 7.05,
#  239: 11.8,
#  250: 18.35,
#  255: 6.4,
#  275: 19.35,
#  279: 17.85,
#  282: 9.0,
#  284: 11.1,
#  291: 10.695,
#  294: 20.2,
#  300: 17.35,
#  301: 20.2,
#  313: 13.0,
#  319: 5.98,
#  320: 9.3,
#  328: 18.0,
#  331: 15.1,
#  333: 13.8,
#  334: 15.6,
#  335: 21.1,
#  340: 17.2,
#  344: 18.75,
#  357: 19.35,
#  359: 8.985,
#  364: 17.7,
#  370: 15.1,
#  371: 18.35,
#  380: 20.35,
#  381: 18.2,
#  388: 14.65,
#  393: 13.35,
#  400: 10.895,
#  404: 15.6,
#  405: 6.8,
#  409: 18.85,
#  417: 10.6,
#  430: 5.765,
#  433: 17.25,
#  434: 5.86,
#  446: 8.895,
#  449: 19.5,
#  456: 20.35,
#  458: 16.75,
#  472: 16.85,
#  485: 13.35,
#  487: 13.1,
#  489: 15.85,
#  490: 15.7,
#  491: 8.0,
#  497: 15.5,
#  504: 10.895,
#  509: 15.2,
#  518: 20.7,
#  519: 9.895,
#  527: 5.825,
#  537: 17.7,
#  542: 13.0,
#  545: 19.5,
#  552: 13.1,
#  556: 17.75,
#  557: 9.395,
#  563: 9.695,
#  574: 8.365,
#  588: 12.6,
#  598: 20.35,
#  610: 20.5,
#  628: 9.0,
#  630: 15.85,
#  633: 10.895,
#  635: 19.0,
#  640: 17.7,
#  661: 11.5,
#  669: 6.785,
#  685: 19.2,
#  692: 9.195000000000002,
#  694: 8.96,
#  695: 11.1,
#  698: 19.6,
#  700: 18.7,
#  715: 16.1,
#  721: 18.5,
#  723: 11.6,
#  725: 8.1,
#  726: 16.75,
#  739: 6.5200000000000005,
#  742: 7.825,
#  752: 16.1,
#  758: 15.6,
#  770: 14.5,
#  771: 9.8,
#  774: 7.975,
#  775: 16.6,
#  783: 6.67,
#  793: 10.6,
#  795: 8.975,
#  803: 19.7,
#  805: 15.6,
#  809: 10.3,
#  811: 6.675,
#  817: 20.35,
#  824: 11.6,
#  827: 18.5,
#  830: 11.0,
#  832: 13.3,
#  833: 15.7,
#  837: 12.65,
#  841: 18.5,
#  844: 19.2,
#  847: 14.1,
#  849: 19.0,
#  853: 13.6,
#  854: 8.355,
#  857: 12.15,
#  858: 5.88,
#  867: 17.75,
#  876: 15.7,
#  884: 4.589999999999999,
#  892: 10.0,
#  897: 12.5,
#  900: 9.17,
#  911: 16.7,
#  916: 19.5,
#  918: 10.8,
#  920: 10.6,
#  924: 15.7,
#  927: 9.395,
#  933: 19.1,
#  935: 15.25,
#  938: 13.8,
#  946: 9.3,
#  947: 18.5,
#  948: 18.6,
#  952: 10.195,
#  960: 12.15,
#  965: 21.25,
#  976: 12.35,
#  981: 7.5200000000000005,
#  989: 11.65,
#  991: 12.65,
#  999: 20.7,
#  1000: 19.35,
#  1009: 17.75,
#  1014: 7.825,
#  1016: 15.7,
#  1025: 7.275,
#  1028: 10.0,
#  1033: 19.7,
#  1039: 20.2,
#  1040: 15.85,
#  1041: 8.89,
#  1043: 4.61,
#  1046: 5.0,
#  1051: 12.1,
#  1078: 14.6,
#  1080: 7.435,
#  1084: 13.0,
#  1085: 17.6,
#  1088: 13.85,
#  1092: 20.2,
#  1097: 5.785000000000001,
#  1100: 14.15,
#  1101: 17.7,
#  1112: 16.1,
#  1113: 7.475,
#  1127: 6.825,
#  1129: 19.7,
#  1130: 6.365,
#  1131: 20.0,
#  1134: 17.2,
#  1136: 11.35,
#  1138: 20.2,
#  1139: 19.25,
#  1142: 11.8,
#  1149: 12.3,
#  1154: 10.3,
#  1159: 6.035,
#  1171: 17.7,
#  1173: 10.895,
#  1176: 11.65,
#  1177: 17.5,
#  1185: 17.6,
#  1194: 8.63,
#  1204: 19.7,
#  1222: 18.0,
#  1225: 9.195,
#  1240: 8.05,
#  1252: 13.5,
#  1256: 14.0,
#  1264: 19.1,
#  1265: 12.5,
#  1268: 10.195,
#  1280: 13.65,
#  1285: 16.35,
#  1290: 17.85,
#  1303: 9.8,
#  1312: 11.65,
#  1313: 19.2,
#  1324: 17.85,
#  1329: 14.8,
#  1338: 19.35,
#  1350: 5.615,
#  1363: 6.78,
#  1366: 8.26,
#  1374: 12.15,
#  1379: 15.1,
#  1386: 6.59,
#  1393: 15.35,
#  1397: 12.15,
#  1409: 11.3,
#  1414: 7.81,
#  1416: 9.035,
#  1423: 13.0,
#  1429: 15.0,
#  1434: 16.85,
#  1436: 6.71,
#  1441: 8.895,
#  1445: 15.2,
#  1450: 16.1,
#  1454: 5.325,
#  1455: 14.5,
#  1462: 15.2,
#  1467: 12.8,
#  1472: 17.6,
#  1478: 19.35,
#  1485: 10.8,
#  1489: 11.6,
#  1490: 9.6,
#  1501: 17.1,
#  1504: 6.235,
#  1514: 16.85,
#  1523: 12.6,
#  1524: 12.6,
#  1531: 13.0,
#  1540: 12.1,
#  1553: 15.6,
#  1556: 20.6,
#  1560: 19.6,
#  1565: 8.895,
#  1569: 10.395,
#  1572: 7.3,
#  1575: 5.365,
#  1579: 18.25,
#  1588: 20.5,
#  1591: 12.8,
#  1594: 18.85,
#  1599: 20.75,
#  1611: 13.6,
#  1619: 17.6,
#  1627: 6.695,
#  1670: 13.0,
#  1671: 15.25,
#  1672: 8.935,
#  1675: 7.93,
#  1680: 16.7,
#  1688: 15.85,
#  1689: 12.6,
#  1699: 6.63,
#  1700: 20.25,
#  1701: 18.85,
#  1706: 9.5,
#  1708: 5.73,
#  1710: 15.2,
#  1713: 13.5,
#  1740: 15.2,
#  1752: 19.6,
#  1758: 7.905,
#  1765: 19.85,
#  1774: 10.5,
#  1776: 7.05,
#  1779: 13.8,
#  1789: 15.6,
#  1791: 6.15,
#  1804: 10.195,
#  1805: 8.985,
#  1807: 9.8,
#  1814: 11.15,
#  1827: 20.35,
#  1829: 17.85,
#  1847: 19.35,
#  1859: 7.68,
#  1865: 11.15,
#  1880: 10.395,
#  1887: 12.6,
#  1889: 19.6,
#  1896: 14.65,
#  1902: 12.15,
#  1906: 5.095,
#  1913: 14.15,
#  1914: 18.35,
#  1922: 10.195,
#  1924: 16.1,
#  1929: 9.195,
#  1932: 9.42,
#  1941: 6.235,
#  1949: 5.86,
#  1961: 19.5,
#  1962: 10.5,
#  1966: 19.5,
#  1968: 5.03,
#  1970: 6.69,
#  1976: 20.35,
#  1977: 13.8,
#  1987: 11.3,
#  1989: 9.0,
#  1996: 18.25,
#  1998: 11.0,
#  2009: 11.8,
#  2010: 12.65,
#  2014: 18.2,
#  2015: 15.7,
#  2019: 10.8,
#  2021: 13.65,
#  2035: 5.44,
#  2050: 5.34,
#  2053: 6.13,
#  2055: 7.8549999999999995,
#  2062: 9.195000000000002,
#  2073: 21.25,
#  2083: 17.1,
#  2084: 9.6,
#  2099: 19.6,
#  2102: 14.1,
#  2109: 16.2,
#  2132: 6.3,
#  2139: 20.25,
#  2141: 12.15,
#  2153: 7.935,
#  2161: 15.15,
#  2164: 6.635,
#  2177: 12.5,
#  2186: 8.63,
#  2200: 20.0,
#  2208: 19.75,
#  2209: 21.0,
#  2229: 8.6,
#  2238: 10.8,
#  2239: 12.1,
#  2242: 13.65,
#  2251: 15.1,
#  2264: 17.85,
#  2265: 12.6,
#  2271: 20.1,
#  2276: 5.19,
#  2305: 20.7,
#  2315: 16.5,
#  2320: 21.35,
#  2322: 18.85,
#  2325: 8.63,
#  2326: 18.7,
#  2327: 20.25,
#  2334: 6.67,
#  2337: 20.1,
#  2357: 8.88,
#  2378: 9.5,
#  2395: 19.25,
#  2401: 11.8,
#  2402: 14.0,
#  2403: 12.85,
#  2424: 5.78,
#  2425: 20.25,
#  2430: 18.2,
#  2431: 9.395,
#  2432: 17.6,
#  2433: 8.18,
#  2435: 15.85,
#  2437: 10.5,
#  2439: 17.0,
#  2446: 20.5,
#  2475: 19.35,
#  2476: 20.7,
#  2484: 11.65,
#  2486: 8.575,
#  2492: 8.365,
#  2500: 15.2,
#  2508: 19.0,
#  2518: 11.8,
#  2522: 7.535,
#  2529: 12.65,
#  2533: 12.3,
#  2550: 15.85,
#  2557: 7.8549999999999995,
#  2563: 11.5,
#  2567: 16.7,
#  2571: 11.8,
#  2581: 9.395,
#  2585: 19.2,
#  2586: 12.85,
#  2589: 20.35,
#  2595: 11.1,
#  2598: 5.985,
#  2613: 10.85,
#  2615: 12.8,
#  2635: 16.35,
#  2641: 15.85,
#  2642: 12.15,
#  2648: 12.85,
#  2659: 8.18,
#  2660: 14.0,
#  2663: 6.55,
#  2665: 13.65,
#  2669: 8.235,
#  2675: 19.2,
#  2687: 7.5,
#  2693: 14.5,
#  2702: 19.35,
#  2715: 13.15,
#  2718: 16.2,
#  2723: 15.0,
#  2742: 14.35,
#  2750: 10.5,
#  2753: 13.85,
#  2758: 8.775,
#  2764: 12.35,
#  2766: 6.135,
#  2770: 6.46,
#  2782: 5.82,
#  2794: 19.5,
#  2800: 6.13,
#  2808: 9.395,
#  2821: 10.1,
#  2827: 14.15,
#  2832: 17.7,
#  2838: 14.35,
#  2840: 14.5,
#  2842: 12.8,
#  2849: 11.8,
#  2863: 15.15,
#  2864: 10.195000000000002,
#  2866: 4.805,
#  2867: 13.1,
#  2879: 19.35,
#  2884: 16.1,
#  2889: 16.25,
#  2895: 12.35,
#  2896: 7.235,
#  2901: 7.35,
#  2912: 10.3,
#  2920: 8.895,
#  2922: 10.1,
#  2927: 5.92,
#  2928: 6.325,
#  2931: 14.15,
#  2933: 18.25,
#  2945: 10.195000000000002,
#  2948: 10.3,
#  2949: 16.0,
#  2950: 10.6,
#  2959: 18.85,
#  2961: 11.8,
#  2962: 15.1,
#  2967: 12.85,
#  2968: 13.3,
#  2982: 16.75,
#  2995: 9.895,
#  3005: 14.8,
#  3006: 8.27,
#  3007: 15.5,
#  3009: 20.25,
#  3017: 12.15,
#  3018: 19.2,
#  3023: 11.35,
#  3029: 9.195000000000002,
#  3039: 5.175,
#  3046: 7.3,
#  3048: 5.325,
#  3053: 12.35,
#  3058: 19.1,
#  3062: 8.395,
#  3076: 20.6,
#  3094: 13.85,
#  3098: 8.945,
#  3107: 12.6,
#  3110: 17.6,
#  3114: 7.51,
#  3126: 6.765,
#  3128: 12.3,
#  3152: 6.36,
#  3154: 21.0,
#  3157: 7.785000000000001,
#  3160: 17.35,
#  3164: 5.035,
#  3192: 8.51,
#  3197: 11.35,
#  3199: 6.44,
#  3204: 12.65,
#  3205: 12.3,
#  3206: 11.1,
#  3213: 17.1,
#  3217: 18.0,
#  3231: 15.35,
#  3234: 20.2,
#  3237: 19.2,
#  3249: 10.5,
#  3252: 13.5,
#  3256: 7.26,
#  3269: 6.55,
#  3277: 9.3,
#  3286: 12.6,
#  3288: 13.85,
#  3293: 8.185,
#  3306: 20.35,
#  3315: 6.15,
#  3320: 8.785,
#  3321: 17.6,
#  3323: 15.7,
#  3333: 18.6,
#  3341: 15.85,
#  3347: 12.5,
#  3354: 17.75,
#  3361: 14.3,
#  3363: 5.615,
#  3366: 18.1,
#  3372: 16.7,
#  3375: 10.3,
#  3390: 6.635,
#  3395: 13.1,
#  3398: 9.1,
#  3404: 17.85,
#  3407: 7.475,
#  3414: 16.7,
#  3420: 13.15,
#  3423: 18.0,
#  3436: 11.6,
#  3440: 5.985,
#  3458: 9.5,
#  3474: 9.1,
#  3482: 18.25,
#  3483: 11.65,
#  3484: 9.13,
#  3491: 6.75,
#  3503: 15.6,
#  3507: 14.0,
#  3511: 6.525,
#  3515: 20.85,
#  3516: 6.57,
#  3518: 12.6,
#  3529: 14.5,
#  3540: 14.65,
#  3543: 13.35,
#  3545: 18.35,
#  3550: 12.1,
#  3552: 20.25,
#  3576: 12.3,
#  3585: 5.175,
#  3598: 8.97,
#  3613: 19.6,
#  3618: 7.63,
#  3635: 12.15,
#  3645: 8.785,
#  3649: 11.3,
#  3652: 16.25,
#  3658: 16.2,
#  3660: 15.2,
#  3661: 7.07,
#  3667: 18.7,
#  3674: 9.3,
#  3689: 16.2,
#  3691: 12.3,
#  3703: 15.6,
#  3706: 8.895,
#  3709: 6.865,
#  3720: 6.86,
#  3721: 6.035,
#  3724: 12.85,
#  3726: 10.5,
#  3733: 7.39,
#  3750: 7.825,
#  3753: 7.71,
#  3757: 12.5,
#  3758: 9.0,
#  3767: 18.6,
#  3768: 17.1,
#  3769: 5.94,
#  3770: 19.1,
#  3773: 7.97,
#  3777: 7.275,
#  3780: 20.2,
#  3803: 9.6,
#  3807: 19.6,
#  3809: 15.2,
#  3811: 20.5,
#  3822: 19.7,
#  3824: 7.785000000000001,
#  3825: 16.25,
#  3833: 14.3,
#  3836: 19.75,
#  3848: 17.0,
#  3851: 19.2,
#  3864: 9.42,
#  3866: 19.6,
#  3869: 10.0,
#  3884: 10.3,
#  3896: 11.0,
#  3903: 11.6,
#  3910: 15.2,
#  3915: 6.785,
#  3922: 18.35,
#  3928: 8.5,
#  3935: 19.5,
#  3940: 8.895,
#  3945: 7.72,
#  3948: 8.775,
#  3956: 18.35,
#  3968: 8.71,
#  3976: 10.695,
#  3993: 13.8,
#  3994: 11.0,
#  4004: 7.59,
#  4006: 12.65,
#  4009: 15.1,
#  4013: 9.0,
#  4020: 20.1,
#  4026: 18.6,
#  4027: 17.75,
#  4028: 7.8549999999999995,
#  4031: 16.75,
#  4043: 21.2,
#  4046: 13.5,
#  4047: 6.78,
#  4050: 14.8,
#  4055: 15.75,
#  4060: 18.35,
#  4063: 11.5,
#  4075: 8.77,
#  4076: 20.7,
#  4078: 18.5,
#  4081: 11.6,
#  4083: 21.2,
#  4101: 10.8,
#  4105: 17.5,
#  4108: 7.5200000000000005,
#  4115: 21.1,
#  4126: 16.7,
#  4136: 8.945,
#  4141: 7.97,
#  4147: 13.1,
#  4148: 13.3,
#  4165: 17.6,
#  4175: 15.0,
#  4180: 19.35,
#  4184: 9.8,
#  4187: 10.395,
#  4192: 5.425,
#  4193: 6.135,
#  4207: 8.85,
#  4208: 11.8,
#  4222: 16.25,
#  4233: 7.285,
#  4248: 16.5,
#  4263: 9.3,
#  4272: 17.35,
#  4287: 13.1,
#  4290: 16.75,
#  4295: 20.25,
#  4296: 6.175,
#  4298: 8.3,
#  4315: 18.7,
#  4337: 16.0,
#  4338: 10.395,
#  4346: 16.75,
#  4349: 18.7,
#  4354: 5.32,
#  4368: 20.2,
#  4375: 7.565,
#  4377: 4.555,
#  4378: 17.7,
#  4381: 6.985,
#  4382: 19.85,
#  4383: 5.75,
#  4389: 15.35,
#  4392: 10.65,
#  4397: 7.325,
#  4401: 9.8,
#  4410: 15.2,
#  4416: 19.35,
#  4427: 20.1,
#  4434: 11.65,
#  4451: 8.1,
#  4457: 10.6,
#  4462: 7.865,
#  4467: 6.885,
#  4472: 7.725,
#  4478: 16.0,
#  4493: 7.55,
#  4494: 16.85,
#  4495: 14.15,
#  4498: 14.5,
#  4504: 15.6,
#  4515: 9.0,
#  4516: 11.0,
#  4517: 10.5,
#  4523: 6.59,
#  4537: 11.5,
#  4538: 6.465,
#  4540: 15.1,
#  4552: 13.65,
#  4554: 16.25,
#  4555: 12.15,
#  4559: 11.1,
#  4560: 13.15,
#  4567: 7.39,
#  4570: 18.75,
#  4583: 5.155,
#  4588: 19.6,
#  4589: 8.325,
#  4594: 6.03,
#  4598: 13.35,
#  4599: 18.0,
#  4600: 18.2,
#  4601: 12.3,
#  4604: 14.1,
#  4608: 6.575,
#  4611: 14.0,
#  4620: 10.5,
#  4624: 15.35,
#  4631: 5.695,
#  4634: 8.42,
#  4637: 20.25,
#  4645: 9.195000000000002,
#  4647: 6.305,
#  4663: 5.26,
#  4670: 15.2,
#  4674: 17.35,
#  4676: 20.75,
#  4681: 9.6,
#  4688: 10.395,
#  4690: 5.785,
#  4705: 16.2,
#  4715: 9.0,
#  4717: 6.635,
#  4721: 7.36,
#  4726: 13.35,
#  4728: 6.055,
#  4734: 5.4,
#  4736: 7.42,
#  4744: 6.635,
#  4746: 18.0,
#  4748: 7.27,
#  4751: 7.97,
#  4759: 15.0,
#  4767: 13.15,
#  4772: 19.5,
#  4785: 12.1,
#  4793: 18.2,
#  4796: 19.1,
#  4803: 18.2,
#  4812: 17.6,
#  4814: 9.6,
#  4822: 5.735,
#  4827: 19.35,
#  4829: 18.85,
#  4832: 6.825,
#  4835: 8.67,
#  4839: 5.464999999999999,
#  4861: 7.2700000000000005,
#  4868: 17.35,
#  4871: 9.6,
#  4873: 10.8,
#  4897: 5.405,
#  4901: 6.895,
#  4913: 9.695000000000002,
#  4929: 8.355,
#  4930: 19.35,
#  4938: 8.85,
#  4943: 8.895,
#  4949: 15.2,
#  4951: 12.1,
#  4954: 7.56,
#  4957: 20.6,
#  4964: 15.1,
#  4968: 16.7,
#  4981: 6.55,
#  5003: 19.75,
#  5022: 6.195,
#  5027: 17.0,
#  5039: 10.8,
#  5043: 6.96,
#  5058: 9.0,
#  5063: 7.27,
#  5065: 18.25,
#  5070: 18.6,
#  5075: 5.98,
#  5084: 8.185,
#  5090: 5.655,
#  5092: 12.1,
#  5101: 7.8549999999999995,
#  5103: 18.35,
#  5106: 14.5,
#  5108: 17.7,
#  5113: 4.805,
#  5118: 8.39,
#  5122: 7.8950000000000005,
#  5124: 16.0,
#  5135: 11.35,
#  5869: 13.65,
#  5871: 14.0,
#  5875: 10.695,
#  5879: 6.965,
#  5880: 13.15,
#  5894: 12.0,
#  5919: 16.7,
#  5920: 6.78,
#  5933: 7.09,
#  5934: 14.65,
#  5935: 10.195,
#  5937: 16.75,
#  5940: 11.8,
#  5946: 7.63,
#  5951: 7.02,
#  5954: 9.5,
#  5957: 8.905,
#  5967: 11.15,
#  ...}

# %%
df[null_feature] = df[null_feature].fillna(replace_series)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# source                          0
# dtype: int64

# %% [markdown]
# ### Outlet_Size

# %%
null_feature = 'Outlet_Size'
df[null_feature].value_counts()
# Out:
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
df[null_feature].replace(np.NaN,'Unknown',inplace=True)
df[null_feature].value_counts()
# Out:
# Medium     4655
# Unknown    4016
# Small      3980
# High       1553
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# **Imput null by group feature have high corr with column**

# %%
feature = "Outlet_Size"
feature_cmp = "Outlet_Type"
display(df[feature].value_counts())
table = df.pivot_table(values = feature,index = feature_cmp,aggfunc  =(lambda x : mode(x).mode[0]))
display(table)
df[feature].replace("Unknown","Small",inplace = True)
display(df[feature].value_counts())
# Out:
# Medium     4655
# Unknown    4016
# Small      3980
# High       1553
# Name: Outlet_Size, dtype: int64
# <ipython-input-45-8a4f684cafed>:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   table = df.pivot_table(values = feature,index = feature_cmp,aggfunc  =(lambda x : mode(x).mode[0]))
#                   Outlet_Size
# Outlet_Type
# Grocery Store         Unknown
# Supermarket Type1       Small
# Supermarket Type2      Medium
# Supermarket Type3      Medium
# Small     7996
# Medium    4655
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
# Check number null value after impute
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %% [markdown]
# ### Item_Visibility

# %% [markdown]
# **Value in Item_Visibility equals 0 => it means null val**

# %%
feature = 'Item_Visibility'
null_val = df[df[feature] == 0]
len(null_val)
# Out:
# 879

# %%
df[feature].replace(to_replace=0,value=np.nan,inplace=True)

# %%
df[feature].isnull().sum()
# Out:
# 879

# %% [markdown]
# **Using mean of item visibility of item_type in each outlet type to impute mean**

# %%
feature1 = "Item_Type"
feature2 = "Outlet_Type"
table_weight = df.pivot_table(values = feature, index = feature1, columns = feature2, aggfunc = "mean")
display(table)
# Out:
#                   Outlet_Size
# Outlet_Type
# Grocery Store         Unknown
# Supermarket Type1       Small
# Supermarket Type2      Medium
# Supermarket Type3      Medium

# %%
index_null = list(df[df[feature].isnull()].index)
len(index_null)
# Out:
# 879

# %%
replace_Nan = {idx : table_weight.loc[df.loc[idx,feature1],df.loc[idx,feature2]] for idx in index_null}
replace_Nan
# Out:
# {3: 0.11482041604508196,
#  4: 0.057773584386554624,
#  5: 0.06820630164814814,
#  10: 0.06712286710406504,
#  32: 0.0655840844854369,
#  33: 0.06757858803149606,
#  46: 0.055021476279773156,
#  60: 0.06750319383743841,
#  72: 0.06673038879878049,
#  79: 0.06616748249554896,
#  107: 0.06669243444817073,
#  114: 0.06757858803149606,
#  144: 0.0654494379438717,
#  156: 0.06820630164814814,
#  175: 0.1116115009090909,
#  212: 0.06557787661282467,
#  214: 0.09928847342408377,
#  216: 0.11482041604508196,
#  219: 0.05867607597954545,
#  228: 0.06616748249554896,
#  307: 0.06418416345454545,
#  13264: 0.12074218385925928,
#  13309: 0.057773584386554624,
#  13310: 0.0654494379438717,
#  13329: 0.11466048869162995,
#  13338: 0.06669243444817073,
#  13351: 0.06929896191666667,
#  13358: 0.05867607597954545,
#  13364: 0.06929896191666667,
#  13370: 0.06557787661282467,
#  13388: 0.06616748249554896,
#  13402: 0.06557787661282467,
#  13409: 0.065485350875,
#  13429: 0.09928847342408377,
#  13437: 0.11589494693103448,
#  13441: 0.055021476279773156,
#  13443: 0.06712286710406504,
#  13461: 0.05867607597954545,
#  13466: 0.06712286710406504,
#  13487: 0.06616748249554896,
#  13492: 0.0654494379438717,
#  13504: 0.0654494379438717,
#  13536: 0.06557787661282467,
#  13575: 0.05867607597954545,
#  13586: 0.0643033685258427,
#  13613: 0.06418416345454545,
#  13617: 0.06616748249554896,
#  13632: 0.06673038879878049,
#  13660: 0.06675767216019418,
#  13677: 0.05867607597954545,
#  13679: 0.05867607597954545,
#  13688: 0.057773584386554624,
#  13702: 0.05867607597954545,
#  13716: 0.06557787661282467,
#  13744: 0.06900015771052632,
#  13749: 0.0643033685258427,
#  13754: 0.055021476279773156,
#  13780: 0.06616748249554896,
#  13783: 0.055688240227544906,
#  13804: 0.0655840844854369,
#  13811: 0.0654494379438717,
#  13814: 0.06929896191666667,
#  13819: 0.06557787661282467,
#  13822: 0.06712286710406504,
#  13847: 0.0692133486637931,
#  13849: 0.06557787661282467,
#  13857: 0.0679757915116279,
#  13894: 0.06929896191666667,
#  13933: 0.05867607597954545,
#  13939: 0.06834015121428572,
#  13973: 0.116306182259542,
#  14029: 0.06750319383743841,
#  14034: 0.055688240227544906,
#  14041: 0.05857407965789473,
#  14042: 0.06675767216019418,
#  14047: 0.07999292157017544,
#  14053: 0.053080534965116284,
#  14060: 0.05867607597954545,
#  14066: 0.06557787661282467,
#  14079: 0.06616748249554896,
#  14112: 0.057857513012820515,
#  14120: 0.06750319383743841,
#  14126: 0.05867607597954545,
#  14134: 0.053080534965116284,
#  14137: 0.06712286710406504,
#  14158: 0.055021476279773156,
#  14166: 0.11482041604508196,
#  14171: 0.06754932577192982,
#  14177: 0.06557787661282467,
#  14184: 0.065485350875,
#  14202: 0.06616748249554896}

# %%
# Impute NaN
df[feature].fillna(replace_Nan,inplace=True)

# %%
df[feature].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.114820
# 4           NCD19         8.93          Low Fat         0.057774
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %% [markdown]
# ## Oulier Handling

# %%
outlier_columns
# Out:
# ['Item_Visibility', 'Item_Outlet_Sales']

# %% [markdown]
# **`Item_Outlet_Sales` is output so we must handle `Item_Visibility`**

# %%
feature = "Item_Visibility"
q1,q2,q3 =np.quantile(df[feature].values,0.25),np.quantile(df[feature].values,0.5),np.quantile(df[feature].values,0.75)
iqr = q3 - q1
lower_bound,upper_bound = q1 - 1.5*iqr,q3 + 1.5*iqr
# Getting outlier data
outlier_data = df[(df[feature] < lower_bound) | (df[feature]> upper_bound)].index
print(f"Number of outlier value in {feature} is {len(outlier_data)}")
df = df.drop(outlier_data)
df.shape
# Out:
# Number of outlier value in Item_Visibility is 274
# (13930, 13)

# %% [markdown]
# ## Skew

# %%
df.skew()
# Out:
# <ipython-input-58-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Item_Weight                  0.098637
# Item_Visibility              0.778393
# Item_MRP                     0.129996
# Outlet_Establishment_Year   -0.416124
# Item_Outlet_Sales            1.517896
# dtype: float64

# %%
sns.histplot(df['Item_Visibility'])
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Count'>

# %% [markdown]
# **We need to reducre skew in this feature**

# %%
feature = 'Item_Visibility'
df[feature] = np.sqrt(df[feature])
sns.histplot(df[feature])
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Count'>

# %%
# Step 4. Feature Engineering : 
# Skewness/Inconsistent/Missing/Outlier Handling, 
# Feature Enrichment, Feature Transformation, Feature Selection, Feature Encoding, 
# Feature Scaling (Normalization & Standardization)

# %% [markdown]
# ## Feature Enrichment

# %%
# Caculate age of each store
date_time = datetime.now()
df['Age'] = date_time.year - df['Outlet_Establishment_Year']
df['Age']
# Out:
# 0        24
# 1        14
# 2        24
# 3        25
# 4        36
#          ..
# 14199    26
# 14200    14
# 14201    21
# 14202    16
# 14203    21
# Name: Age, Length: 13930, dtype: int64

# %% [markdown]
# **Remove feature `Outlet_Establishment_Year`**

# %%
df.drop('Outlet_Establishment_Year',axis = 1,inplace=True)
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales', 'source',
#        'Age'],
#       dtype='object')

# %% [markdown]
# ## Feature Transformation

# %%
df['Item_Identifier']
# Out:
# 0        FDA15
# 1        DRC01
# 2        FDN15
# 3        FDX07
# 4        NCD19
#          ...
# 14199    FDB58
# 14200    FDD47
# 14201    NCO17
# 14202    FDJ26
# 14203    FDU37
# Name: Item_Identifier, Length: 13930, dtype: object

# %% [markdown]
# **Remove digit in `Item_Identifier`**

# %%
feature = 'Item_Identifier'
df[feature] = df[feature].apply(lambda x : x[:-2])

# %%
df[feature]
# Out:
# 0        F
# 1        D
# 2        F
# 3        F
# 4        N
#         ..
# 14199    F
# 14200    F
# 14201    N
# 14202    F
# 14203    F
# Name: Item_Identifier, Length: 13930, dtype: object

# %% [markdown]
# ## Feature Selection

# %%
target = 'Item_Outlet_Sales'
df.corr()[target].sort_values(ascending=False)
# Out:
# <ipython-input-68-0cafaa58461e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()[target].sort_values(ascending=False)
# Item_Outlet_Sales    1.000000
# Item_MRP             0.345988
# Age                  0.040005
# Item_Weight          0.020073
# Item_Visibility     -0.041740
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# **In this project, we will use all of features**

# %% [markdown]
# ## Feature Encoding

# %% [markdown]
# **We do not use `source` for train => remove source to encode**

# %%
encode_col = [col for col in category_col if col != 'source']
dict_encode = {}
for col in encode_col:
    encode = LabelEncoder()
    df[col] = encode.fit_transform(df[[col]])
    dict_encode[col] = encode
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Check encode have done
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0                1         9.30                 0         0.126678          4
# 1                0         5.92                 1         0.138846         14
# 2                1        17.50                 0         0.129461         10
# 3                1        19.20                 1         0.338852          6
# 4                2         8.93                 0         0.240361          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Location_Type  \
# 0  249.8092                  9            1                     0
# 1   48.2692                  3            1                     2
# 2  141.6180                  9            1                     0
# 3  182.0950                  0            2                     2
# 4   53.8614                  1            0                     2
#
#    Outlet_Type  Item_Outlet_Sales source  Age
# 0            1          3735.1380  train   24
# 1            2           443.4228  train   14
# 2            1          2097.2700  train   24
# 3            0           732.3800  train   25
# 4            1           994.7052  train   36

# %% [markdown]
# ## Scaling

# %%
scaler_column = [col for col in df.columns if col != 'source' and col != target]
scaler_column
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Age']

# %%
dict_scaler = {}
for col in scaler_column:
    scaler = StandardScaler()
    df[col] = scaler.fit_transform(df[[col]])
    dict_scaler[col] = scaler

# %%
# Check columns is scaled
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0        -0.185868    -0.752825         -0.737102        -1.425593  -0.768335
# 1        -2.096677    -1.479171          1.356664        -1.278981   1.606975
# 2        -0.185868     1.009316         -0.737102        -1.392063   0.656851
# 3        -0.185868     1.374637          1.356664         1.130860  -0.293273
# 4         1.724940    -0.832336         -0.737102        -0.055836   0.419320
#
#    Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Location_Type  \
# 0  1.751709            1.49517    -0.646175             -1.379913
# 1 -1.495094           -0.62823    -0.646175              1.094144
# 2  0.008752            1.49517    -0.646175             -1.379913
# 3  0.660836           -1.68993     0.812930              1.094144
# 4 -1.405004           -1.33603    -2.105280              1.094144
#
#    Outlet_Type  Item_Outlet_Sales source       Age
# 0    -0.286105          3735.1380  train -0.124732
# 1     0.985978           443.4228  train -1.321781
# 2    -0.286105          2097.2700  train -0.124732
# 3    -1.558188           732.3800  train -0.005027
# 4    -0.286105           994.7052  train  1.311727

# %%
# Step 5. Dataset Partition : 
# Train Test Split 
# Step 6. Data Modelling : 
# Try many ML methods
# Step 7. Data Evaluation : 
# Display Metrics for Classification (Accuracy, Precision, Recall), 
# Display Metrics for Regression (R2Score, MSE, RMSE)
# Step 8. Hyper-parameter Tuning : 
# Tuning parameters: Cross Validation (CV), GridSearchCV, Regularization (L1, L2 penalty)
# Step 9. Build the pipeline with the best Model with the best parameters
# Choose best hyper-parameters and build best models
# Step 10. Conclusion

# %% [markdown]
# ## Train and Test Split data

# %%
target = 'Item_Outlet_Sales'
target
# Out:
# 'Item_Outlet_Sales'

# %%
X= df[df['source'] == 'train'].drop(columns = [target,'source'])
y = df.loc[X.index,target]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=123)
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (5854, 2509, 5854, 2509)

# %% [markdown]
# # Data Modelling

# %%
model =RandomForestRegressor()

# %%
result = {'RMSE' : [],'MSE' : [],'MAE' :[]}

model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(f"RMSE: {mean_squared_error(y_test,y_pred,squared=False)}")
print(f"MSE: {mean_squared_error(y_test,y_pred,squared=True)}")
print(f"MAE: {mean_squared_error(y_test,y_pred)}")
# Out:
# RMSE: 1151.6438305845281
# MSE: 1326283.5125234055
# MAE: 1326283.5125234055

# %% [markdown]
# >**The RMSE value**, 1151.6438305845281, indicates that, on average, the predicted values deviate from the actual values by approximately 1151.64 units.
#
# >**The MSE value** , 1326283.5125234055, represents the average squared difference between the predicted and actual values.
#
# >**The MAE value**, 1326283.5125234055, represents the average absolute difference between the predicted and actual values.
